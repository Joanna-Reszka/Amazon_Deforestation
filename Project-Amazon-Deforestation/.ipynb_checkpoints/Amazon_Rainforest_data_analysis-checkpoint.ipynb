# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ### Data Cleaning and data transformation

# %% [markdown]
# #### FIRST TABLE with deforested area in square km each year [2004-2019] in each state

# %%
df_def = pd.read_csv('def_area_2004_2019.csv')
df_def
# Out:
#     Ano/Estados   AC    AM   AP    MA     MT    PA    RO   RR   TO  AMZ LEGAL
# 0          2004  728  1232   46   755  11814  8870  3858  311  158      27772
# 1          2005  592   775   33   922   7145  5899  3244  133  271      19014
# 2          2006  398   788   30   674   4333  5659  2049  231  124      14286
# 3          2007  184   610   39   631   2678  5526  1611  309   63      11651
# 4          2008  254   604  100  1271   3258  5607  1136  574  107      12911
# 5          2009  167   405   70   828   1049  4281   482  121   61       7464
# 6          2010  259   595   53   712    871  3770   435  256   49       7000
# 7          2011  280   502   66   396   1120  3008   865  141   40       6418
# 8          2012  305   523   27   269    757  1741   773  124   52       4571
# 9          2013  221   583   23   403   1139  2346   932  170   74       5891
# 10         2014  309   500   31   257   1075  1887   684  219   50       5012
# 11         2015  264   712   25   209   1601  2153  1030  156   57       6207
# 12         2016  372  1129   17   258   1489  2992  1376  202   58       7893
# 13         2017  257  1001   24   265   1561  2433  1243  132   31       6947
# 14         2018  444  1045   24   253   1490  2744  1316  195   25       7536
# 15         2019  688  1421    8   215   1685  3862  1245  617   21       9762

# %%
# Renaming columns with full names of states
df_def.columns = ['Year', 'Acre', 'Amazonas', 'Amapa', 'Maranhao','Mato Grosso','Para',\
                  'Rondonia','Roraima', 'Tocantins', 'Total_deforestation']

# %%
df_def = df_def.drop('Total_deforestation', axis =1)

# %%
# transforming data frame ('unpivot') to have states stacked in one column
df_def =df_def.melt(id_vars = ['Year'], var_name='state')

# %%
# renaming columns
df_def.columns = ['year', 'state','def_area']
df_def
# Out:
#      year      state  def_area
# 0    2004       Acre       728
# 1    2005       Acre       592
# 2    2006       Acre       398
# 3    2007       Acre       184
# 4    2008       Acre       254
# ..    ...        ...       ...
# 139  2015  Tocantins        57
# 140  2016  Tocantins        58
# 141  2017  Tocantins        31
# 142  2018  Tocantins        25
# 143  2019  Tocantins        21
#
# [144 rows x 3 columns]

# %% [markdown]
# #### SECOND TABLE with nr of firespots each month each year [1999-2019] in each state

# %%
df_fires = pd.read_csv('inpe_brazilian_amazon_fires_1999_2019.csv')
df_fires
# Out:
#       year  month        state   latitude  longitude  firespots
# 0     1999      1     AMAZONAS  -2.371113 -59.899933          3
# 1     1999      1     MARANHAO  -2.257395 -45.487831         36
# 2     1999      1  MATO GROSSO -12.660633 -55.057989         18
# 3     1999      1         PARA  -2.474820 -48.546967         87
# 4     1999      1     RONDONIA -12.861700 -60.513100          1
# ...    ...    ...          ...        ...        ...        ...
# 2099  2019     12  MATO GROSSO -12.138385 -56.066297        148
# 2100  2019     12         PARA  -2.976727 -50.909316       1280
# 2101  2019     12     RONDONIA -10.809262 -62.890452         42
# 2102  2019     12      RORAIMA   2.856667 -60.431963         27
# 2103  2019     12    TOCANTINS  -6.769381 -48.475667         21
#
# [2104 rows x 6 columns]

# %%
# Changing State names to titles instead of capitalized
df_fires['state'] =df_fires['state'].str.title()

# %%
# Adding column with sum of firespots by year
df_fires['fires']=df_fires.groupby(['year','state'])['firespots'].transform('sum')
#yearly_fires=arr.to_frame(name ='fires')
#yearly_fires
df_fires
# Out:
#       year  month        state   latitude  longitude  firespots  fires
# 0     1999      1     Amazonas  -2.371113 -59.899933          3   1048
# 1     1999      1     Maranhao  -2.257395 -45.487831         36   4136
# 2     1999      1  Mato Grosso -12.660633 -55.057989         18  28538
# 3     1999      1         Para  -2.474820 -48.546967         87  20478
# 4     1999      1     Rondonia -12.861700 -60.513100          1   7121
# ...    ...    ...          ...        ...        ...        ...    ...
# 2099  2019     12  Mato Grosso -12.138385 -56.066297        148  17479
# 2100  2019     12         Para  -2.976727 -50.909316       1280  29700
# 2101  2019     12     Rondonia -10.809262 -62.890452         42  11206
# 2102  2019     12      Roraima   2.856667 -60.431963         27   4775
# 2103  2019     12    Tocantins  -6.769381 -48.475667         21    247
#
# [2104 rows x 7 columns]

# %%
# Reducing dataframe to only rows with yearly fires per state
df_fires.groupby('month').count()
# Out:
#        year  state  fires  latitude  longitude  firespots
# month
# 1       169    169    169       169        169        169
# 2       158    158    158       158        158        158
# 3       153    153    153       153        153        153
# 4       160    160    160       160        160        160
# 5       169    169    169       169        169        169
# 6       177    177    177       177        177        177
# 7       183    183    183       183        183        183
# 8       188    188    188       188        188        188
# 9       189    189    189       189        189        189
# 10      189    189    189       189        189        189
# 11      188    188    188       188        188        188
# 12      181    181    181       181        181        181

# %%
df_fires= df_fires[df_fires.month ==9]
df_fires
# Out:
#       year        state  fires  month   latitude  longitude  firespots
# 2     1999         Acre    347      9  -9.829269 -68.230805        212
# 8     1999        Amapa    101      9   0.614518 -51.110725          4
# 19    1999     Amazonas   1048      9  -8.000527 -64.045189        214
# 28    1999     Maranhao   4136      9  -4.309715 -46.404073        375
# 40    1999  Mato Grosso  28538      9 -11.958582 -56.094235       7357
# ...    ...          ...    ...    ...        ...        ...        ...
# 2052  2019  Mato Grosso  17479      9 -11.215601 -56.421694       5165
# 2064  2019         Para  29700      9  -5.952494 -52.249601       4618
# 2076  2019     Rondonia  11206      9 -10.194926 -63.488670       3644
# 2088  2019      Roraima   4775      9   2.697000 -61.105615         26
# 2100  2019    Tocantins    247      9  -7.062450 -48.643700         40
#
# [189 rows x 7 columns]

# %%
df_fires = df_fires.drop(['month', 'firespots'], axis=1)
df_fires
# Out:
#       year        state  fires   latitude  longitude
# 2     1999         Acre    347  -9.829269 -68.230805
# 8     1999        Amapa    101   0.614518 -51.110725
# 19    1999     Amazonas   1048  -8.000527 -64.045189
# 28    1999     Maranhao   4136  -4.309715 -46.404073
# 40    1999  Mato Grosso  28538 -11.958582 -56.094235
# ...    ...          ...    ...        ...        ...
# 2052  2019  Mato Grosso  17479 -11.215601 -56.421694
# 2064  2019         Para  29700  -5.952494 -52.249601
# 2076  2019     Rondonia  11206 -10.194926 -63.488670
# 2088  2019      Roraima   4775   2.697000 -61.105615
# 2100  2019    Tocantins    247  -7.062450 -48.643700
#
# [189 rows x 5 columns]

# %%
df_fires.isnull().sum()
# Out:
# year         0
# state        0
# fires        0
# latitude     0
# longitude    0
# dtype: int64

# %%
# merging dataframe with deforested area [2004-2009] with dataframe with fires [2004-2019]
df_def_fires =df_def.merge(df_fires, on = ['year','state'], how = 'left')
df_def_fires
# Out:
#      year      state  def_area  fires  latitude  longitude
# 0    2004       Acre       728   7271 -9.835523 -68.803959
# 1    2005       Acre       592  15993 -9.737740 -68.922445
# 2    2006       Acre       398   6198 -9.225773 -69.480164
# 3    2007       Acre       184   8549 -9.545272 -69.254333
# 4    2008       Acre       254   5699 -9.331973 -69.572583
# ..    ...        ...       ...    ...       ...        ...
# 139  2015  Tocantins        57    509 -6.949110 -48.549937
# 140  2016  Tocantins        58    489 -7.309605 -48.765383
# 141  2017  Tocantins        31    841 -6.950014 -48.567056
# 142  2018  Tocantins        25    281 -6.952400 -48.582556
# 143  2019  Tocantins        21    247 -7.062450 -48.643700
#
# [144 rows x 6 columns]

# %%
df_def_fires.isnull().sum()
# Out:
# year         0
# state        0
# def_area     0
# fires        0
# latitude     0
# longitude    0
# dtype: int64

# %% [markdown]
# #### THIRD TABLE with information on appearance of El Ninio or La nina and its severity

# %%
df_nino = pd.read_csv('el_nino_la_nina_1999_2019.csv')
df_nino
# Out:
#     start year  end year phenomenon     severity
# 0         2004      2005    El Nino         Weak
# 1         2006      2007    El Nino         Weak
# 2         2014      2015    El Nino         Weak
# 3         2018      2019    El Nino         Weak
# 4         2002      2003    El Nino     Moderate
# 5         2009      2010    El Nino     Moderate
# 6         2015      2016    El Nino  Very Strong
# 7         2000      2001    La Nina         Weak
# 8         2005      2006    La Nina         Weak
# 9         2008      2009    La Nina         Weak
# 10        2016      2017    La Nina         Weak
# 11        2017      2018    La Nina         Weak
# 12        2011      2012    La Nina     Moderate
# 13        1999      2000    La Nina       Strong
# 14        2007      2008    La Nina       Strong
# 15        2010      2011    La Nina       Strong

# %%
# Replacing categorical variable 'Severity' with ordered numbers
df_nino['severity'] = df_nino['severity'].replace(['Very Strong','Strong','Moderate','Weak'],
                        [4,3,2,1])
df_nino
# Out:
#     start year  end year phenomenon  severity
# 0         2004      2005    El Nino         1
# 1         2006      2007    El Nino         1
# 2         2014      2015    El Nino         1
# 3         2018      2019    El Nino         1
# 4         2002      2003    El Nino         2
# 5         2009      2010    El Nino         2
# 6         2015      2016    El Nino         4
# 7         2000      2001    La Nina         1
# 8         2005      2006    La Nina         1
# 9         2008      2009    La Nina         1
# 10        2016      2017    La Nina         1
# 11        2017      2018    La Nina         1
# 12        2011      2012    La Nina         2
# 13        1999      2000    La Nina         3
# 14        2007      2008    La Nina         3
# 15        2010      2011    La Nina         3

# %%
df_nino.groupby('phenomenon').count()
# Out:
#             start year  end year  severity
# phenomenon
# El Nino              7         7         7
# La Nina              9         9         9

# %%
df_nino =df_nino.sort_values('phenomenon')

# %%
# Transforming severity values for La Ninia to negative values to distinguis the influence of 
# humidity with La Nina from dryness of El Nino
df_nino.iloc[7:,3] *= -1
df_nino
# Out:
#     start year  end year phenomenon  severity
# 0         2004      2005    El Nino         1
# 1         2006      2007    El Nino         1
# 2         2014      2015    El Nino         1
# 3         2018      2019    El Nino         1
# 4         2002      2003    El Nino         2
# 5         2009      2010    El Nino         2
# 6         2015      2016    El Nino         4
# 7         2000      2001    La Nina        -1
# 8         2005      2006    La Nina        -1
# 9         2008      2009    La Nina        -1
# 10        2016      2017    La Nina        -1
# 11        2017      2018    La Nina        -1
# 12        2011      2012    La Nina        -2
# 13        1999      2000    La Nina        -3
# 14        2007      2008    La Nina        -3
# 15        2010      2011    La Nina        -3

# %%
# Merging all three dataframes into one dataframe
df_all =df_def_fires.merge(df_nino, left_on='year', right_on='start year', how ='left')
df_all
# Out:
#      year      state  def_area  fires  latitude  longitude  start year
# 0    2004       Acre       728   7271 -9.835523 -68.803959      2004.0  \
# 1    2005       Acre       592  15993 -9.737740 -68.922445      2005.0
# 2    2006       Acre       398   6198 -9.225773 -69.480164      2006.0
# 3    2007       Acre       184   8549 -9.545272 -69.254333      2007.0
# 4    2008       Acre       254   5699 -9.331973 -69.572583      2008.0
# ..    ...        ...       ...    ...       ...        ...         ...
# 139  2015  Tocantins        57    509 -6.949110 -48.549937      2015.0
# 140  2016  Tocantins        58    489 -7.309605 -48.765383      2016.0
# 141  2017  Tocantins        31    841 -6.950014 -48.567056      2017.0
# 142  2018  Tocantins        25    281 -6.952400 -48.582556      2018.0
# 143  2019  Tocantins        21    247 -7.062450 -48.643700         NaN
#
#      end year phenomenon  severity
# 0      2005.0    El Nino       1.0
# 1      2006.0    La Nina      -1.0
# 2      2007.0    El Nino       1.0
# 3      2008.0    La Nina      -3.0
# 4      2009.0    La Nina      -1.0
# ..        ...        ...       ...
# 139    2016.0    El Nino       4.0
# 140    2017.0    La Nina      -1.0
# 141    2018.0    La Nina      -1.0
# 142    2019.0    El Nino       1.0
# 143       NaN        NaN       NaN
#
# [144 rows x 10 columns]

# %%
# checking for missing values
df_all.isnull().sum()
# Out:
# year           0
# state          0
# def_area       0
# fires          0
# latitude       0
# longitude      0
# start year    27
# end year      27
# phenomenon    27
# severity      27
# dtype: int64

# %%
df_all[df_all.isnull().any(axis=1)]
# Out:
#      year        state  def_area  fires   latitude  longitude  start year
# 8    2012         Acre       305   4720  -9.259102 -69.990269         NaN  \
# 9    2013         Acre       221   4980  -9.429270 -69.807078         NaN
# 15   2019         Acre       688   6802  -9.508821 -69.634697         NaN
# 24   2012     Amazonas       523   9114  -6.870559 -63.915696         NaN
# 25   2013     Amazonas       583   6512  -6.443141 -63.947691         NaN
# 31   2019     Amazonas      1421  12665  -6.889662 -64.389371         NaN
# 40   2012        Amapa        27   2518   1.755081 -51.155439         NaN
# 41   2013        Amapa        23   1529   1.034294 -51.108992         NaN
# 47   2019        Amapa         8   1272   1.152261 -51.069623         NaN
# 56   2012     Maranhao       269   6919  -4.528343 -46.150702         NaN
# 57   2013     Maranhao       403   4418  -3.577913 -45.823902         NaN
# 63   2019     Maranhao       215   3989  -3.634704 -45.754942         NaN
# 72   2012  Mato Grosso       757  16133 -11.276386 -56.153321         NaN
# 73   2013  Mato Grosso      1139  10830 -10.971679 -56.493620         NaN
# 79   2019  Mato Grosso      1685  17479 -11.215601 -56.421694         NaN
# 88   2012         Para      1741  37221  -6.209192 -52.006116         NaN
# 89   2013         Para      2346  24046  -5.963970 -51.525518         NaN
# 95   2019         Para      3862  29700  -5.952494 -52.249601         NaN
# 104  2012     Rondonia       773   8312 -10.164545 -63.428017         NaN
# 105  2013     Rondonia       932   4613 -10.257129 -63.399355         NaN
# 111  2019     Rondonia      1245  11206 -10.194926 -63.488670         NaN
# 120  2012      Roraima       124   1376   3.479337 -60.627528         NaN
# 121  2013      Roraima       170   1395   3.150103 -60.741923         NaN
# 127  2019      Roraima       617   4775   2.697000 -61.105615         NaN
# 136  2012    Tocantins        52    406  -6.950126 -48.455943         NaN
# 137  2013    Tocantins        74    365  -7.300512 -48.663772         NaN
# 143  2019    Tocantins        21    247  -7.062450 -48.643700         NaN
#
#      end year phenomenon  severity
# 8         NaN        NaN       NaN
# 9         NaN        NaN       NaN
# 15        NaN        NaN       NaN
# 24        NaN        NaN       NaN
# 25        NaN        NaN       NaN
# 31        NaN        NaN       NaN
# 40        NaN        NaN       NaN
# 41        NaN        NaN       NaN
# 47        NaN        NaN       NaN
# 56        NaN        NaN       NaN
# 57        NaN        NaN       NaN
# 63        NaN        NaN       NaN
# 72        NaN        NaN       NaN
# 73        NaN        NaN       NaN
# 79        NaN        NaN       NaN
# 88        NaN        NaN       NaN
# 89        NaN        NaN       NaN
# 95        NaN        NaN       NaN
# 104       NaN        NaN       NaN
# 105       NaN        NaN       NaN
# 111       NaN        NaN       NaN
# 120       NaN        NaN       NaN
# 121       NaN        NaN       NaN
# 127       NaN        NaN       NaN
# 136       NaN        NaN       NaN
# 137       NaN        NaN       NaN
# 143       NaN        NaN       NaN

# %%
# Replacing missing values in years where there was neither La Nina or El Nino observed
# with None for "phenomenon", 0 for "severity", "year" for "start year" and "year"+1 for "end year"
df_all['phenomenon'].fillna('None', inplace = True)
df_all['severity'].fillna('0', inplace = True)
df_all['severity'].fillna('0', inplace = True)
df_all['start year'].fillna(df_all['year'], inplace=True)
df_all['end year'].fillna(df_all['year']+1, inplace=True)
df_all
# Out:
#      year      state  def_area  fires  latitude  longitude  start year
# 0    2004       Acre       728   7271 -9.835523 -68.803959      2004.0  \
# 1    2005       Acre       592  15993 -9.737740 -68.922445      2005.0
# 2    2006       Acre       398   6198 -9.225773 -69.480164      2006.0
# 3    2007       Acre       184   8549 -9.545272 -69.254333      2007.0
# 4    2008       Acre       254   5699 -9.331973 -69.572583      2008.0
# ..    ...        ...       ...    ...       ...        ...         ...
# 139  2015  Tocantins        57    509 -6.949110 -48.549937      2015.0
# 140  2016  Tocantins        58    489 -7.309605 -48.765383      2016.0
# 141  2017  Tocantins        31    841 -6.950014 -48.567056      2017.0
# 142  2018  Tocantins        25    281 -6.952400 -48.582556      2018.0
# 143  2019  Tocantins        21    247 -7.062450 -48.643700         NaN
#
#      end year phenomenon severity
# 0      2005.0    El Nino      1.0
# 1      2006.0    La Nina     -1.0
# 2      2007.0    El Nino      1.0
# 3      2008.0    La Nina     -3.0
# 4      2009.0    La Nina     -1.0
# ..        ...        ...      ...
# 139    2016.0    El Nino      4.0
# 140    2017.0    La Nina     -1.0
# 141    2018.0    La Nina     -1.0
# 142    2019.0    El Nino      1.0
# 143       NaN       None        0
#
# [144 rows x 10 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   year        144 non-null    int64
#  1   state       144 non-null    object
#  2   def_area    144 non-null    int64
#  3   fires       144 non-null    int64
#  4   latitude    144 non-null    float64
#  5   longitude   144 non-null    float64
#  6   start year  144 non-null    float64
#  7   end year    144 non-null    float64
#  8   phenomenon  144 non-null    object
#  9   severity    144 non-null    object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 11.4+ KB

# %%
# replacing floats with integer values
df_all[['fires', 'start year','end year', 'severity']] = df_all[['fires', 'start year','end year', 'severity']].astype(int)
df_all
# Out:
#      year      state  def_area  fires  latitude  longitude  start year
# 0    2004       Acre       728   7271 -9.835523 -68.803959        2004  \
# 1    2005       Acre       592  15993 -9.737740 -68.922445        2005
# 2    2006       Acre       398   6198 -9.225773 -69.480164        2006
# 3    2007       Acre       184   8549 -9.545272 -69.254333        2007
# 4    2008       Acre       254   5699 -9.331973 -69.572583        2008
# ..    ...        ...       ...    ...       ...        ...         ...
# 139  2015  Tocantins        57    509 -6.949110 -48.549937        2015
# 140  2016  Tocantins        58    489 -7.309605 -48.765383        2016
# 141  2017  Tocantins        31    841 -6.950014 -48.567056        2017
# 142  2018  Tocantins        25    281 -6.952400 -48.582556        2018
# 143  2019  Tocantins        21    247 -7.062450 -48.643700        2019
#
#      end year phenomenon  severity
# 0        2005    El Nino         1
# 1        2006    La Nina        -1
# 2        2007    El Nino         1
# 3        2008    La Nina        -3
# 4        2009    La Nina        -1
# ..        ...        ...       ...
# 139      2016    El Nino         4
# 140      2017    La Nina        -1
# 141      2018    La Nina        -1
# 142      2019    El Nino         1
# 143      2020       None         0
#
# [144 rows x 10 columns]

# %% [markdown]
# #### FOURTH ADDITIONAL TABLE with area of each state (km 2), forested area in 2001 and 2020
# #### data form: https://rainforests.mongabay.com/brazil/

# %%
df_area= pd.read_csv('state_area_plus_country.csv')
df_area
# Out:
#   country        state  total_area  primary_forest_area_2001
# 0  Brazil         Acre      164123                 135056.90  \
# 1  Brazil        Amapa      142829                 109346.45
# 2  Brazil     Amazonas     1559159                1434851.83
# 3  Brazil     Maranhao      331937                  31857.32
# 4  Brazil  Mato_Grosso      903366                 390096.45
# 5  Brazil         Para     1247955                 922258.96
# 6  Brazil     Rondonia      237591                 156495.78
# 7  Brazil      Roraima      224301                 154257.59
# 8  Brazil    Tocantins      277721                  11949.96
#
#    primary_forest_area_2020
# 0                 125834.18
# 1                 107922.68
# 2                1412174.83
# 3                  24831.53
# 4                 316969.53
# 5                 835769.73
# 6                 124705.63
# 7                 146837.38
# 8                   9956.71

# %%
# Changing column names, rounding and changing type from float to integer
df_area['state']= df_area['state'].str.replace('Mato_Grosso', 'Mato Grosso')
df_area.columns =['country', 'state', 'total_area', 'forest_area_2001', 'forest_area_2020']
df_area['forest_area_2001'] =round(df_area['forest_area_2001'])
df_area['forest_area_2020'] =round(df_area['forest_area_2020'])
df_area[['forest_area_2001','forest_area_2020']] = df_area[['forest_area_2001','forest_area_2020']].astype(int)
df_area
# Out:
#   country        state  total_area  forest_area_2001  forest_area_2020
# 0  Brazil         Acre      164123            135057            125834
# 1  Brazil        Amapa      142829            109346            107923
# 2  Brazil     Amazonas     1559159           1434852           1412175
# 3  Brazil     Maranhao      331937             31857             24832
# 4  Brazil  Mato Grosso      903366            390096            316970
# 5  Brazil         Para     1247955            922259            835770
# 6  Brazil     Rondonia      237591            156496            124706
# 7  Brazil      Roraima      224301            154258            146837
# 8  Brazil    Tocantins      277721             11950              9957

# %% [markdown]
# ### Exploratory Data Analysis

# %%
# Calculating percent of forested area in each state, area of deforestation between 2001-2020,
# and percent of deforested area in comparison to forest coverage in 2001
df_area['forest_2001_percent']= round(((df_area['forest_area_2001']/ df_area['total_area'])*100),1)
df_area['deforested_2001_2020']= df_area['forest_area_2001']- df_area['forest_area_2020']
df_area['deforested_percent']= round((df_area['deforested_2001_2020']/df_area['forest_area_2001'])*100,1)
df_area
# Out:
#   country        state  total_area  forest_area_2001  forest_area_2020
# 0  Brazil         Acre      164123          135057.0          125834.0  \
# 1  Brazil        Amapa      142829          109346.0          107923.0
# 2  Brazil     Amazonas     1559159         1434852.0         1412175.0
# 3  Brazil     Maranhao      331937           31857.0           24832.0
# 4  Brazil  Mato Grosso      903366          390096.0          316970.0
# 5  Brazil         Para     1247955          922259.0          835770.0
# 6  Brazil     Rondonia      237591          156496.0          124706.0
# 7  Brazil      Roraima      224301          154258.0          146837.0
# 8  Brazil    Tocantins      277721           11950.0            9957.0
#
#    forest_2001_percent
# 0                 82.3
# 1                 76.6
# 2                 92.0
# 3                  9.6
# 4                 43.2
# 5                 73.9
# 6                 65.9
# 7                 68.8
# 8                  4.3

# %% [markdown]
# Map Charts made in Tableau showing:
# 1) primary forest coverage in each state in 2001
# 2) percent of deforested area till 2020
# 3) deforested area till 2020

# %% [markdown]
# ![obraz.png](attachment:54973c2a-a42b-4c59-bd31-95e7077a64f1.png)

# %%
grouped = df_all.groupby('year')['def_area'].sum()
grouped
# Out:
# year
# 2004    27772
# 2005    19014
# 2006    14286
# 2007    11651
# 2008    12911
# 2009     7464
# 2010     7000
# 2011     6418
# 2012     4571
# 2013     5891
# 2014     5012
# 2015     6207
# 2016     7893
# 2017     6947
# 2018     7536
# 2019     9762
# Name: def_area, dtype: int64

# %%
cumulative =grouped.cumsum(axis=0)
cumulative
# Out:
# year
# 2004     27772
# 2005     46786
# 2006     61072
# 2007     72723
# 2008     85634
# 2009     93098
# 2010    100098
# 2011    106516
# 2012    111087
# 2013    116978
# 2014    121990
# 2015    128197
# 2016    136090
# 2017    143037
# 2018    150573
# 2019    160335
# Name: def_area, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.set_context("paper", rc={"font.size":10,"axes.titlesize":16,"axes.labelsize":15})
grouped.plot(kind='bar', y='def_area', title='Intensity of deforestation 2004-2019',ax=ax, xlabel ='Years', ylabel = 'Deforested area [km 2]', fontsize = 10)
ax2 = ax.twinx()
cumulative.plot(kind ='line', secondary_y = True, ax=ax2)
plt.show()

# %%
cumulative.plot(kind ='area', secondary_y = True)
# Out:
# <AxesSubplot: >

# %%
values = ['Acre', 'Amazonas', 'Amapa', 'Maranhao','Mato Grosso','Para',\
                  'Rondonia','Roraima', 'Tocantins']

plt.figure(figsize=(25,20))
for i in range(9):
    plt.subplot(3,3,i+1)
    sns.lineplot(data = df_all[df_all["state"] == values[i]], x='year', y='def_area')
    #set_ylabel(values[i],fontsize=20)
    #axes.set_title(values[i],fontsize=50)
plt.show()

# %% [markdown]
# ![obraz.png](attachment:6acc9f21-5867-4ca7-b231-e890658610b1.png)

# %%
grouped2 = df_all.groupby('year')['fires'].sum()

# %%
fig, ax = plt.subplots(figsize=(10,10))
sns.set_context("paper", rc={"font.size":10,"axes.titlesize":16,"axes.labelsize":15})
#grouped.plot(kind='bar', y='def_area', title='Intensity of deforestation 2004-2019',ax=ax, xlabel ='Years', ylabel = 'Deforested area [km 2]', fontsize = 10)
ax2 = ax.twinx()
grouped2.plot(kind ='line', secondary_y = True, ax=ax2, color = 'red')
plt.show()

# %%
values = ['Acre', 'Amazonas', 'Amapa', 'Maranhao','Mato Grosso','Para',\
                  'Rondonia','Roraima', 'Tocantins']

plt.figure(figsize=(25,20))
for i in range(9):
    plt.subplot(3,3,i+1)
    sns.lineplot(data = df_all[df_all["state"] == values[i]], x='year', y='fires', color ='red')
    #set_ylabel(values[i],fontsize=20)
    #axes.set_title(values[i],fontsize=50)
plt.show()

# %% [markdown]
# ![obraz.png](attachment:64aa382a-e961-4765-910f-9197454a5000.png)

# %%
from scipy.stats import pearsonr
sns.regplot(data =df_all, x ='def_area', y='fires')
# Out:
# <AxesSubplot: xlabel='def_area', ylabel='fires'>

# %%
values = ['Acre', 'Amazonas', 'Amapa', 'Maranhao','Mato Grosso','Para',\
                  'Rondonia','Roraima', 'Tocantins']

plt.figure(figsize=(25,20))
for i in range(9):
    plt.subplot(3,3,i+1)
    sns.regplot(data = df_all[df_all["state"] == values[i]], x='def_area', y='fires')
    #set_ylabel(values[i],fontsize=20)
    #axes.set_title(values[i],fontsize=50)
plt.show()

# %%
df_all[['def_area','fires']].corr()
# Out:
#           def_area     fires
# def_area  1.000000  0.906022
# fires     0.906022  1.000000
